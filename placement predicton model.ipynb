# %% [markdown]
# <a href="https://colab.research.google.com/github/DharmendraKumarSingh-ai/Placement-Prediction-Project-Using-Logistic-Regression/blob/main/placement%20predicton%20model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Placement Prediction Model Using Linear Regression**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
 df = pd.read_csv('/content/placement.csv')

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
 plt.scatter( df['cgpa'] , df['iq'] , c = df['placement'] )

# %%
X = (df.iloc[:,0:2])
y = (df.iloc[:,-1])

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 94   4.7   52.0
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
#
# [99 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 94    0
# 95    0
# 96    0
# 97    1
# 98    1
# Name: placement, Length: 99, dtype: int64

# %%
X.shape
# Out:
# (99, 2)

# %%
y.shape
# Out:
# (99,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.26080635,  1.14717055],
#        [-0.26080635,  0.38778425],
#        [ 0.46456131,  0.91149894],
#        [ 0.2832194 ,  0.07355543],
#        [-1.80221264, -1.3142885 ],
#        [ 0.10187748,  0.17829837],
#        [-0.98617401,  0.78057027],
#        [-0.26080635,  0.17829837],
#        [-0.98617401, -1.68088879],
#        [-0.89550306, -0.89531675],
#        [ 1.46194185, -0.94768822],
#        [-0.26080635,  0.46634145],
#        [ 0.9179161 ,  1.30428496],
#        [ 1.00858706, -2.02130334],
#        [-0.8048321 ,  0.07355543],
#        [-0.71416114, -0.92150248],
#        [ 1.18992898, -0.24067338],
#        [ 0.9179161 , -0.34541632],
#        [ 1.64328377, -0.29304485],
#        [-1.07684497, -0.34541632],
#        [ 0.10187748, -0.58108793],
#        [-0.53281922, -0.47634499],
#        [ 0.01120652, -1.54996011],
#        [-1.07684497,  0.99005615],
#        [ 0.10187748, -1.15717409],
#        [-0.98617401,  0.23066984],
#        [-0.71416114, -0.39778779],
# ...

# %%
X_test = scaler.fit_transform(X_test)

# %%
X_test
# Out:
# array([[ 1.71781753,  0.19002775],
#        [-0.61841431, -0.8678587 ],
#        [ 0.48098891,  1.40463812],
#        [-1.16811592,  1.75726693],
#        [-0.41227621,  0.56224706],
#        [ 1.03069052, -0.96581115],
#        [-0.82455242,  0.60142804],
#        [ 1.37425403, -0.61318233],
#        [-0.89326512, -1.14212555],
#        [-0.68712701, -0.92663017]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
x = clf.fit(X_train,y_train)

# %%
x
# Out:
# LogisticRegression()

# %%
 y_predict = clf.predict(X_test)

# %%
clf.predict_proba(X_test)
# Out:
# array([[0.00441962, 0.99558038],
#        [0.87163218, 0.12836782],
#        [0.20333316, 0.79666684],
#        [0.98045989, 0.01954011],
#        [0.80158725, 0.19841275],
#        [0.03418021, 0.96581979],
#        [0.93772218, 0.06227782],
#        [0.0121184 , 0.9878816 ],
#        [0.94068927, 0.05931073],
#        [0.89364184, 0.10635816]])

# %%
y_predict
# Out:
# array([1, 0, 1, 0, 0, 1, 0, 1, 0, 0])

# %%
y_test
# Out:
# 69    1
# 9     0
# 97    1
# 95    0
# 12    0
# 44    1
# 51    0
# 58    1
# 94    0
# 7     0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_predict)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_predict)

# %%
cm
# Out:
# array([[6, 0],
#        [0, 4]])

# %%
from sklearn.metrics import precision_score

precision = precision_score(y_test, y_predict)

print("Precision:", precision)
# Out:
# Precision: 1.0

# %%
from sklearn.metrics import recall_score

recall = recall_score(y_test, y_predict)

print("Recall:", recall)
# Out:
# Recall: 1.0

# %%
from sklearn.metrics import f1_score

f1 = f1_score(y_test, y_predict)

print("F1-Score:", f1)
# Out:
# F1-Score: 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >
